# %% [markdown]
# # Performace Expectation Heatmap

# %% [markdown]
# ## Methodology
#
# Based on match data provided by babygogogo, I've tried to make a performace expectation heatmap of the characters in TinyWars based on how these make positive or negative contributions to the win expectation $W_e$. Given by the standard elo formula, $W_e$ can be represented as:
#
# $$
# W_e = \dfrac{1}{1 + 10^{\frac{R_o - R_p}{400}}}
# $$
#
# Where $R_o$ is the opponent's elo rating and $R_p$ is the player's own elo _at the start of the match_. Such that the performance $P$ of the character picked in a given match is calculated as:
#
# $$
# P = A - W_e
# $$
#
# Where $A$ is the actual result of the match, with a win represented as a $1$ and a loss as a $0$. In other words, the difference between the expected outcome and the actual outcome is atributed to be the CO's influence solely. A $P$ value of $1$ would theoretically imply certainty of victory regardless of the skill of the players involved, while $-1$ would similarly imply selecting "resign" at the character selection screen. That's why the values you'll see here are so low.
#
# ### Sample
#
# Only ranked or tourney matches that weren't mirror matches or ended in a draw were accounted.
#
# ### Reverse engineering the Elo's at the start of the match
#
# The dataset baby gave us has only the player's elo ratings $R_p'$ at the end of the match, after these were corrected with the Elo update formula:
#
# $$
# R'_p = R_p + K \times (A - W_e)
# $$
#
# If you expand $W_e$, you'll see $R_p$ as a term of the expression and as an expoent, which makes this expression _non-linear_. So what I did to figure out the previous Elo's was plug into $R_p$ and $R_o$ values with various difference intervals until I got one that produced the resulting elos. The search was optimized using a [binary search algorithm](https://en.wikipedia.org/wiki/Binary_search) seen in the auxiliary function `revert_elo`.
#
# #### Note
#
# As the Elo formula uses floats (i.e. it has decimal values because it performs a division) the integer Elo rating we see in game are actually **rounded results**. As such, due to rounding, more than one starting Elo combination can produce the resulting Elo combination. So much so that the mathcup heatmap by the end of this notebook changes ratings slightly each time it is run. But do note the the average performance and relative position in the tier list of every character remains **stable**.
#
# ### Minimizing discrepancies due to low game counts
#
# Some matchups are so underrepresented (i.e.: Zhao faced against Gage+ only once) that assigning a character's performance based on them would lead to severe distortions. For that reason I've used a [Weighted Bayesian average](https://en.wikipedia.org/wiki/Bayesian_average) (WBA) to calculate the matchup performance ratings $\overline P$. The formula for the WBA is given as:
#
# $$
# \overline P = \dfrac{C \times p + \sum^n_i = 1 P_i}{C + n}
# $$
#
# Where:
#
# - $C$ is the confidence constant, here set to 15 as it was calculated to be the average number of games per matchup.
# - $p$ is the prior performance here set to 0.
#
# So to the raw average are added 15 "phantom" games where the character pick is said to not have impacted the player's chances at all. This makes a single win less significant to that character's rating, but with more and more real games, the less significant these phantom games become. The matchup rating function.

# %% [markdown]
# ## Dependencies

# %%
import math
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from tqdm import tqdm
from dataclasses import dataclass
from sqlalchemy import create_engine, select, join, func, distinct, desc, asc
from sqlalchemy.orm import sessionmaker as sm
from utils.tables import Match, Player, CO, User

# %% [markdown]
# ## Auxliliary functions

# %%
def elo_win_expectation(winner_elo: int, loser_elo: int) -> float:
    return 1 / (1 + 10 ** ((loser_elo - winner_elo) / 400))
    
def max_elo_variation(k_factor: float = 90) -> int:
    diff = 0

    engine = create_engine("sqlite:///TinyWars.db")
    Session = sm(bind=engine)
    with Session() as session:
        highest_query = select(User).order_by(desc(User.elo)).limit(1)
        highest_player = session.execute(highest_query).scalar_one()

        # Get lowest ranked player (excluding players with None ELO)
        lowest_query = (
            select(User).where(User.elo.isnot(None)).order_by(asc(User.elo)).limit(1)
        )
        lowest_player = session.execute(lowest_query).scalar_one()
        diff = highest_player.elo - lowest_player.elo

    return int(round(diff))

def revert_elo(
    winner_new_elo: int,
    loser_new_elo: int,
    max_elo_variation: int,
    k_factor: float = 90, 
) -> tuple[int, int]:
    new_diff = float(winner_new_elo - loser_new_elo)


    def calculate_new_difference(old_diff: float) -> float:
        winner_win_exp = 1.0 / (1.0 + math.pow(10.0, -old_diff / 400.0))
        diff_change = 2 * k_factor * (1.0 - 1.0 * winner_win_exp)
        return old_diff + diff_change

    hi = max_elo_variation
    lo = -hi

    while True:
        mid = lo + (hi - lo) / 2
        mid_value = calculate_new_difference(mid)
        if mid_value < new_diff - 0.5:
            lo = mid
        elif mid_value > new_diff + 0.5:
            hi = mid
        else:
            break

    old_diff = mid
    old_winner_win_exp = 1.0 / (1.0 + math.pow(10.0, -old_diff / 400.0))
    winner_old_elo = winner_new_elo - k_factor * (1 - old_winner_win_exp)
    loser_old_elo = winner_old_elo - old_diff

    return int(round(winner_old_elo)), int(round(loser_old_elo))


@dataclass
class MatchInfo():
    player_elo: int
    opponent_elo: int
    result: int 


def matchup_rating(
    matches_data: list[MatchInfo], confidence_constant: int
) -> dict[str, float | int]:
    total_performance = 0
    match_count = len(matches_data)
    if match_count == 0:
        return total_performance, total_performance
    

    for match in matches_data:
        elo_diff = match.player_elo - match.opponent_elo
        expected_result = 1 / (1 + 10**(-elo_diff / 400))
        total_performance += match.result - expected_result
    bayesian_average = total_performance / (confidence_constant + match_count)
    raw_average = total_performance / match_count
    result = {
        "rating": bayesian_average,
        "error margin": raw_average - bayesian_average,
        "match count": match_count
    }
    return result

def display_heatmap(
    title: str,
    label: str,
    df: pd.DataFrame,
    sorted_cos: pd.Series,
    added_col: pd.Series,
    count: bool = False
) -> None:
    df.loc[sorted_cos, sorted_cos]
    addded_col = added_col[sorted_cos]
    n = len(sorted_cos)
    extended_matrix = np.full((n + 1, n + 1), 0.0)
    extended_matrix[:n, :n] = df.values
    extended_matrix[:n, n] = added_col.values
    if count:
        extended_matrix[n, :n] = added_col.values
        extended_index = sorted_cos + ['Total']
        extended_columns = sorted_cos + ['Total']
        cmap = LinearSegmentedColormap.from_list('matchup_cmap', ['white', 'green'])
        fmt='.0f'
    else:
        extended_matrix[n, :n] = -added_col.values  # Bottom row (negative averages)
        extended_index = sorted_cos + ['Average']
        extended_columns = sorted_cos + ['Average']
        cmap = LinearSegmentedColormap.from_list('matchup_cmap', ['red', 'white', 'green'])
        fmt='.3f'
    extended_df = pd.DataFrame(extended_matrix, index=extended_index, columns=extended_columns)

    # Create the heatmap
    plt.figure(figsize=(16, 14))
    # Plot heatmap
    sns.heatmap(
        extended_df,
        cmap=cmap,
        center=0,
        annot=True,
        fmt=fmt,
        mask=np.eye(n + 1, dtype=bool),
        cbar_kws={'label': label},
        square=True,
        linewidths=0.5,
        linecolor='gray'
    )
    
    plt.title(title, fontsize=16, pad=20)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    
    # Add grid lines to separate the average column/row
    plt.axvline(x=n, color='black', linewidth=2)
    plt.axhline(y=n, color='black', linewidth=2)
    
    plt.tight_layout()
    plt.show()

# %%
ROSTER = {
    62001: "Brenner-",
    63000: "Isabella-",
    100001: "Lin",
    10001: "Will",

    40001: "Forsythe",
    53002: "Gage+",
    54002: "Tasha+",

    61000: "Greyfield+",
    64001: "Waylon+",

    110002: "Caulder",
    60000: "Penny+",
    90001: "Tabitha",

    55001: "Cassie",
    59003: "Cyrus",
    12003: "Grat",
    130002: "Hawke",
    66000: "Judy",
    16002: "Lee",
    14003: "Mira",
    65001: "Snowind",
    56001: "The Beast",
    57002: "The Fanatic",
    18003: "Tinker",
    20003: "Zhao",
}

# %% [markdown]
# ## Query database
#
# Fetch all matches in ranked and tourney modes where there's a character of the current roster and populate a Dataframe

# %%
engine = create_engine('sqlite:///TinyWars.db')
Session = sm(bind=engine)

with Session() as session:
    query = (
        select(
            Match.id.label('match_id'),
            Match.winner_id,
            Player.id.label('player_id'),
            Player.co_id,
            Player.resulting_elo,
            CO.name.label('co_name')
        )
        .select_from(
            join(Match, Player, Match.id == Player.match_id)
            .join(CO, Player.co_id == CO.id)
        )
        .where(Match.mode.in_(['ranked', 'tourney'])) # Filter by competitive settings
        .where(Match.winner_id != 0) # Exclude ties
        .where(Player.co_id.in_(ROSTER.keys())) # Filter by current character roster
    )
    result = session.execute(query)
    # Convert to DataFrame
    matches_df = pd.DataFrame(result.fetchall(), columns=[
        'match_id', 'winner_id', 'player_id', 
        'co_id', 'resulting_elo', 'co_name'
    ])
    print(matches_df.tail(10))
# Out:
#        match_id  winner_id  player_id   co_id  resulting_elo       co_name
# 10223      6950          1          1   20003           1698  Zhaotiantong
# 10224      6950          1          2   12003           1212          Grat
# 10225      6941          1          1   12003           1519          Grat
# 10226      6941          1          2   16002           1309           Lee
# 10227      6939          1          2   90001           1212       Tabitha
# 10228      6936          1          1  130002           1279         Hawke
# 10229      6936          1          2  130002           1214         Hawke
# 10230      6924          2          1  100001           1580           Lin
# 10231      6924          2          2   10001           1379          Will
# 10232      6916          2          2   40001           1698      Forsythe

# %% [markdown]
# ## Create MatchInfo Objects and load it to a dictionary
#
# Extract the information we need for the matchup analysis, reverting the update to the players Elo rankings.

# %%
player_count = matches_df.groupby('match_id')['match_id'].transform('size')
unique_cos = matches_df.groupby('match_id')['co_id'].transform('nunique')
matches_df = matches_df[(player_count == 2) & (unique_cos == 2)]

match_groups = matches_df.groupby('match_id')
match_info_dict: dict[tuple[int, int], list[MatchInfo]]= {}
delta = max_elo_variation()

for match_id, match_df in tqdm(match_groups, desc="Processing Match Data"):
    
    # Get player data
    player1 = match_df.iloc[0]
    player2 = match_df.iloc[1]
    co1 = player1['co_id']
    co2 = player2['co_id']
    key = (ROSTER[min(co1, co2)], ROSTER[max(co1, co2)])
    
    if key not in match_info_dict:
        match_info_dict[key] = []
    if match_df['winner_id'].iloc[0] == 1:
        winner_old_elo, loser_old_elo = revert_elo(
            player1['resulting_elo'], player2['resulting_elo'], delta
        )
        if key[0] == ROSTER[co1]:
            match_info = MatchInfo(winner_old_elo, loser_old_elo, 1)
        else:
            match_info = MatchInfo(loser_old_elo, winner_old_elo, 0)
    else:
        winner_old_elo, loser_old_elo = revert_elo(
            player2['resulting_elo'], player1['resulting_elo'], delta
        )
        if key[0] == ROSTER[co2]:
            match_info = MatchInfo(winner_old_elo, loser_old_elo, 1)
        else:
            match_info = MatchInfo(loser_old_elo, winner_old_elo, 0)

    match_info_dict[key].append(match_info)
# Out:
# Processing Match Data: 100%|████████████████████████████████████████████████| 3670/3670 [00:00<00:00, 3871.81it/s]

# %% [markdown]
# ## For each co pairing, calculate the its matchup rating

# %%
matchup_results = {}
total_matches = len(matches_df['match_id'].unique())  # Count unique matches
total_pairings = len(match_info_dict)  # Count unique CO pairings
confidence_constant = int(round(total_matches / total_pairings))

for key, value in match_info_dict.items():
    matchup_results[key] = matchup_rating(value, confidence_constant)

for matchup, result in matchup_results.items():
    print(f"Matchup {matchup}: {result}")
# Out:
# Matchup ('Will', 'Lin'): {'rating': -0.03157399081177812, 'error margin': -0.006231708712850947, 'match count': 76}
# Matchup ('Grat', 'Lee'): {'rating': -0.06857477333783017, 'error margin': -0.2571554000168631, 'match count': 4}
# Matchup ('Grat', 'Zhao'): {'rating': 0.1036625167221246, 'error margin': 0.17277086120354096, 'match count': 9}
# Matchup ('Grat', 'Hawke'): {'rating': -0.16143623313802746, 'error margin': -0.2690603885633791, 'match count': 9}
# Matchup ('Forsythe', 'Tabitha'): {'rating': -0.18435639858262473, 'error margin': -0.07900988510683918, 'match count': 35}
# Matchup ('Grat', 'Tabitha'): {'rating': -0.17766487624435084, 'error margin': -0.14026174440343486, 'match count': 19}
# Matchup ('Lin', 'Hawke'): {'rating': 0.007037354927176592, 'error margin': 0.001954820813104609, 'match count': 54}
# Matchup ('Zhao', 'Tabitha'): {'rating': -0.027095392185784908, 'error margin': -0.04515898697630817, 'match count': 9}
# Matchup ('Grat', 'Caulder'): {'rating': -0.008063382588663518, 'error margin': -0.024190147765990554, 'match count': 5}
# Matchup ('Will', 'Tabitha'): {'rating': -0.1882078951922255, 'error margin': -0.04952839347163829, 'match count': 57}
# Matchup ('Will', 'Caulder'): {'rating': -0.04743875378302961, 'error margin': -0.04185772392620259, 'match count': 17}
# Matchup ('Lee', 'Hawke'): {'rating': -2.8578707892657622e-05, 'error margin': -1.714722473559458e-05, 'match count': 25}
# Matchup ('Lin', 'Caulder'): {'rating': -0.04346216368169295, 'error margin': -0.021731081840846475, 'match count': 30}
# Matchup ('Will', 'Forsythe'): {'rating': 0.07381076956894067, 'error margin': 0.02088984044403981, 'match count': 53}
# Matchup ('Caulder', 'Hawke'): {'rating': 0.12500766033438013, 'error margin': 0.0506787812166406, 'match count': 37}
# Matchup ('Grat', 'Forsythe'): {'rating': -0.10260509065208887, 'error margin': -0.19238454497266663, 'match count': 8}
# Matchup ('Lee', 'Tabitha'): {'rating': -0.05594004461440792, 'error margin': -0.03227310266215842, 'match count': 26}
# Matchup ('Forsythe', 'Lin'): {'rating': 0.07879623012446356, 'error margin': 0.028141510758737, 'match count': 42}
# Matchup ('Will', 'Hawke'): {'rating': -0.05928430975308738, 'error margin': -0.016168448114478373, 'match count': 55}
# Matchup ('Zhao', 'Hawke'): {'rating': -0.0492366036706411, 'error margin': -0.05275350393282975, 'match count': 14}
# Matchup ('Forsythe', 'Caulder'): {'rating': 0.05199107445426426, 'error margin': 0.031194644672558558, 'match count': 25}
# Matchup ('Zhao', 'Forsythe'): {'rating': 0.048274357533566396, 'error margin': 0.10344505185764227, 'match count': 7}
# Matchup ('Forsythe', 'Hawke'): {'rating': 0.03440847834905229, 'error margin': 0.01358229408515222, 'match count': 38}
# Matchup ('Grat', 'Lin'): {'rating': -0.07818245444960688, 'error margin': -0.06515204537467238, 'match count': 18}
# Matchup ('Tabitha', 'Lin'): {'rating': 0.12047004605195238, 'error margin': 0.05475911184179655, 'match count': 33}
# Matchup ('Lee', 'Caulder'): {'rating': 0.07371187459435188, 'error margin': 0.10051619262866165, 'match count': 11}
# Matchup ('Will', 'Grat'): {'rating': 0.08677619170725387, 'error margin': 0.11833117050989164, 'match count': 11}
# Matchup ('Zhao', 'Lin'): {'rating': 0.01516283845114879, 'error margin': 0.02843032209590398, 'match count': 8}
# Matchup ('Tabitha', 'Hawke'): {'rating': -0.01122742708414126, 'error margin': -0.007322235054874735, 'match count': 23}
# Matchup ('Will', 'Lee'): {'rating': -0.04401525105800793, 'error margin': -0.03301143829350595, 'match count': 20}
# Matchup ('Lee', 'Zhao'): {'rating': -0.02172592295136132, 'error margin': -0.032588884427041984, 'match count': 10}
# Matchup ('Tabitha', 'Caulder'): {'rating': -0.06456689962071259, 'error margin': -0.024833422931043292, 'match count': 39}
# Matchup ('Cassie', 'Lin'): {'rating': -0.025694708559584414, 'error margin': -0.009635515709844156, 'match count': 40}
# Matchup ('Will', 'Cassie'): {'rating': 0.04456061487225868, 'error margin': 0.013641004552732247, 'match count': 49}
# Matchup ('Cassie', 'Tabitha'): {'rating': -0.1865784710764826, 'error margin': -0.06508551316621483, 'match count': 43}
# Matchup ('Cassie', 'Caulder'): {'rating': 0.0069073406609930195, 'error margin': 0.004504787387604142, 'match count': 23}
# Matchup ('Lee', 'Cassie'): {'rating': 0.07099225668062081, 'error margin': 0.04629929783518748, 'match count': 23}
# Matchup ('Cassie', 'Hawke'): {'rating': 0.027871276113032518, 'error margin': 0.007888097013122413, 'match count': 53}
# Matchup ('Grat', 'Cassie'): {'rating': 0.0352203420691641, 'error margin': 0.0660381413796827, 'match count': 8}
# Matchup ('Forsythe', 'Cassie'): {'rating': 0.059293187214742284, 'error margin': 0.022234945205528357, 'match count': 40}
# Matchup ('Zhao', 'Cassie'): {'rating': 0.03514016676761477, 'error margin': 0.03514016676761477, 'match count': 15}
# Matchup ('Will', 'Zhao'): {'rating': -0.13143172556280366, 'error margin': -0.14081970596014678, 'match count': 14}
# Matchup ('Zhao', 'Caulder'): {'rating': 0.025014846573072496, 'error margin': 0.07504453971921748, 'match count': 5}
# Matchup ('Lee', 'Lin'): {'rating': 0.025377856926901053, 'error margin': 0.014641071303981373, 'match count': 26}
# Matchup ('Lee', 'Forsythe'): {'rating': -0.04010020071263792, 'error margin': -0.03538253004056287, 'match count': 17}
# Matchup ('Forsythe', 'The Beast'): {'rating': -0.10780516254857017, 'error margin': -0.1243905721714271, 'match count': 13}
# Matchup ('Will', 'The Beast'): {'rating': 0.033107440411764215, 'error margin': 0.02257325482620287, 'match count': 22}
# Matchup ('The Beast', 'Hawke'): {'rating': -0.08056865542728599, 'error margin': -0.0755331144630806, 'match count': 16}
# Matchup ('The Beast', 'Lin'): {'rating': -0.022531504633969412, 'error margin': -0.022531504633969412, 'match count': 15}
# Matchup ('The Beast', 'Tabitha'): {'rating': -0.009224560510216575, 'error margin': -0.006918420382662429, 'match count': 20}
# Matchup ('Zhao', 'The Beast'): {'rating': 0.10008102179907176, 'error margin': 0.18765191587325958, 'match count': 8}
# Matchup ('Lee', 'The Beast'): {'rating': -0.006070073932887769, 'error margin': -0.009105110899331654, 'match count': 10}
# Matchup ('Cassie', 'The Beast'): {'rating': -0.014293833959186505, 'error margin': -0.014293833959186505, 'match count': 15}
# Matchup ('Forsythe', 'The Fanatic'): {'rating': 0.022962738754263957, 'error margin': 0.17222054065697967, 'match count': 2}
# Matchup ('The Beast', 'The Fanatic'): {'rating': 0.05529846906388852, 'error margin': 0.2764923453194426, 'match count': 3}
# Matchup ('Grat', 'The Beast'): {'rating': 0.04147338112758096, 'error margin': 0.6221007169137145, 'match count': 1}
# Matchup ('Will', 'The Fanatic'): {'rating': 0.12579338682678826, 'error margin': 0.26955725748597487, 'match count': 7}
# Matchup ('Isabella-', 'Tabitha'): {'rating': -0.12426553439797346, 'error margin': -0.09319915079848008, 'match count': 20}
# Matchup ('Cassie', 'Waylon+'): {'rating': -0.01611896424365895, 'error margin': -0.02198040578680766, 'match count': 11}
# Matchup ('Penny+', 'Greyfield+'): {'rating': 0.01825987716637154, 'error margin': 0.012449916249798777, 'match count': 22}
# Matchup ('Tasha+', 'The Beast'): {'rating': -0.05058969668640155, 'error margin': -0.054203246449715956, 'match count': 14}
# Matchup ('Forsythe', 'Waylon+'): {'rating': 0.08274049054733058, 'error margin': 0.08274049054733058, 'match count': 15}
# Matchup ('Mira', 'Lin'): {'rating': 0.11462610168171028, 'error margin': 0.10114067795445025, 'match count': 17}
# Matchup ('Mira', 'The Fanatic'): {'rating': 0.06450100734469705, 'error margin': 0.19350302203409114, 'match count': 5}
# Matchup ('Gage+', 'Cassie'): {'rating': -0.05380955033772201, 'error margin': -0.0733766595514391, 'match count': 11}
# Matchup ('Gage+', 'Caulder'): {'rating': -0.08342808105195346, 'error margin': -0.20857020262988366, 'match count': 6}
# Matchup ('Penny+', 'Tabitha'): {'rating': -0.12930872356627449, 'error margin': -0.03344191126713997, 'match count': 58}
# Matchup ('Mira', 'Tasha+'): {'rating': -0.005489891757750856, 'error margin': -0.009149819596251427, 'match count': 9}
# Matchup ('Greyfield+', 'Waylon+'): {'rating': 0.01517687953639877, 'error margin': 0.03252188472085451, 'match count': 7}
# Matchup ('Tasha+', 'Brenner-'): {'rating': -0.08706961293067132, 'error margin': -0.0653022096980035, 'match count': 20}
# Matchup ('Will', 'Penny+'): {'rating': 0.0004350978422473945, 'error margin': 0.00016316169084277295, 'match count': 40}
# Matchup ('Waylon+', 'Lin'): {'rating': -0.019423565501488747, 'error margin': -0.0153343938169648, 'match count': 19}
# Matchup ('Zhao', 'Penny+'): {'rating': 0.04394578152713473, 'error margin': 0.05070667099284776, 'match count': 13}
# Matchup ('Gage+', 'Lin'): {'rating': -0.10701766062700808, 'error margin': -0.12348191610808625, 'match count': 13}
# Matchup ('Forsythe', 'Penny+'): {'rating': -0.04777918691274123, 'error margin': -0.020476794391174807, 'match count': 35}
# Matchup ('Gage+', 'Greyfield+'): {'rating': 0.1610196466453866, 'error margin': 0.17252104997719991, 'match count': 14}
# Matchup ('Tasha+', 'Lin'): {'rating': -0.07146606686564623, 'error margin': -0.0893325835820578, 'match count': 12}
# Matchup ('Cassie', 'Greyfield+'): {'rating': 0.0076533785106727825, 'error margin': 0.009566723138340978, 'match count': 12}
# Matchup ('Tinker', 'Gage+'): {'rating': -0.005257346208848196, 'error margin': -0.03943009656636147, 'match count': 2}
# Matchup ('Isabella-', 'Waylon+'): {'rating': -0.010377696315964037, 'error margin': -0.0064860601974775205, 'match count': 24}
# Matchup ('Gage+', 'Brenner-'): {'rating': -0.006750903606635091, 'error margin': -0.0072331110071090264, 'match count': 14}
# Matchup ('Mira', 'Tabitha'): {'rating': -0.025241487610165706, 'error margin': -0.0473277892690607, 'match count': 8}
# Matchup ('Tasha+', 'Greyfield+'): {'rating': 0.11108620008880897, 'error margin': 0.23804185733316208, 'match count': 7}
# Matchup ('Mira', 'Gage+'): {'rating': 0.10034732223084503, 'error margin': 0.2508683055771126, 'match count': 6}
# Matchup ('Mira', 'Isabella-'): {'rating': 0.041563548131369615, 'error margin': 0.03667371893944378, 'match count': 17}
# Matchup ('Greyfield+', 'Tabitha'): {'rating': -0.01807121730139987, 'error margin': -0.0159451917365293, 'match count': 17}
# Matchup ('Penny+', 'Waylon+'): {'rating': 0.005473600756610997, 'error margin': 0.002648516495134353, 'match count': 31}
# Matchup ('Lee', 'Waylon+'): {'rating': 0.1338041749933343, 'error margin': 0.20070626249000145, 'match count': 10}
# Matchup ('Tinker', 'Penny+'): {'rating': 0.005948791503738348, 'error margin': 0.007435989379672934, 'match count': 12}
# Matchup ('Gage+', 'Penny+'): {'rating': 0.004733852370809043, 'error margin': 0.0022189932988167394, 'match count': 32}
# Matchup ('Penny+', 'Hawke'): {'rating': -0.0035350025788840364, 'error margin': -0.00135961637649386, 'match count': 39}
# Matchup ('Will', 'Mira'): {'rating': -0.13088732964763808, 'error margin': -0.1636091620595476, 'match count': 12}
# Matchup ('Gage+', 'Tabitha'): {'rating': 0.00042772717209577885, 'error margin': 0.00032079537907183416, 'match count': 20}
# Matchup ('Penny+', 'Lin'): {'rating': 0.07454894819301328, 'error margin': 0.02033153132536726, 'match count': 55}
# Matchup ('Mira', 'Cassie'): {'rating': 0.11156971734855392, 'error margin': 0.18594952891425653, 'match count': 9}
# Matchup ('Tinker', 'Cassie'): {'rating': 0.06718908888869735, 'error margin': 0.2519590833326151, 'match count': 4}
# Matchup ('Gage+', 'Hawke'): {'rating': 0.029784939613462888, 'error margin': 0.029784939613462888, 'match count': 15}
# Matchup ('Lee', 'Penny+'): {'rating': 0.01631034824936711, 'error margin': 0.010193967655854442, 'match count': 24}
# Matchup ('Tasha+', 'Caulder'): {'rating': -0.030681768541796498, 'error margin': -0.03540204062514982, 'match count': 13}
# Matchup ('Tinker', 'Greyfield+'): {'rating': 0.06817571258866395, 'error margin': 0.34087856294331975, 'match count': 3}
# Matchup ('Penny+', 'Brenner-'): {'rating': -0.06132413908498469, 'error margin': -0.02358620734037873, 'match count': 39}
# Matchup ('Mira', 'Brenner-'): {'rating': 0.04313055619123576, 'error margin': 0.08086979285856705, 'match count': 8}
# Matchup ('Mira', 'Forsythe'): {'rating': -0.0011557999417929551, 'error margin': -0.0019263332363215918, 'match count': 9}
# Matchup ('Tasha+', 'Cassie'): {'rating': -0.03629311724730675, 'error margin': -0.05443967587096012, 'match count': 10}
# Matchup ('Mira', 'Penny+'): {'rating': 0.06550841380837177, 'error margin': 0.07558663131735205, 'match count': 13}
# Matchup ('The Fanatic', 'Penny+'): {'rating': -0.07875654875439195, 'error margin': -0.09844568594298991, 'match count': 12}
# Matchup ('Brenner-', 'Isabella-'): {'rating': -0.05327878995895868, 'error margin': -0.03632644769929001, 'match count': 22}
# Matchup ('Zhao', 'Greyfield+'): {'rating': 0.11062972058044777, 'error margin': 0.2765743014511194, 'match count': 6}
# Matchup ('Lee', 'Isabella-'): {'rating': 0.01827015735280039, 'error margin': 0.01096209441168023, 'match count': 25}
# Matchup ('Brenner-', 'Tabitha'): {'rating': -0.031418894517423836, 'error margin': -0.0261824120978532, 'match count': 18}
# Matchup ('The Fanatic', 'Tabitha'): {'rating': -0.016352094659058746, 'error margin': -0.030660177485735147, 'match count': 8}
# Matchup ('Penny+', 'Isabella-'): {'rating': 0.0014419262582358306, 'error margin': 0.0005545870223983963, 'match count': 39}
# Matchup ('The Beast', 'Isabella-'): {'rating': -0.0325714143347212, 'error margin': -0.03758240115544753, 'match count': 13}
# Matchup ('Will', 'Greyfield+'): {'rating': 0.030051306870292806, 'error margin': 0.06439565757919886, 'match count': 7}
# Matchup ('Zhao', 'Tasha+'): {'rating': 0.04945198326282173, 'error margin': 0.14835594978846517, 'match count': 5}
# Matchup ('Will', 'Tasha+'): {'rating': -0.02258204391963832, 'error margin': -0.014727419947590213, 'match count': 23}
# Matchup ('Cassie', 'Penny+'): {'rating': -0.07315773882879217, 'error margin': -0.037840209739030434, 'match count': 29}
# Matchup ('Greyfield+', 'Isabella-'): {'rating': -0.020799114504021166, 'error margin': -0.044569531080045355, 'match count': 7}
# Matchup ('Forsythe', 'Brenner-'): {'rating': -0.03948421480732177, 'error margin': -0.03483901306528392, 'match count': 17}
# Matchup ('Waylon+', 'Tabitha'): {'rating': -0.02524327044306391, 'error margin': -0.018932452832297934, 'match count': 20}
# Matchup ('Brenner-', 'Caulder'): {'rating': -0.0027864214345942884, 'error margin': -0.0037996655926285754, 'match count': 11}
# Matchup ('Brenner-', 'Waylon+'): {'rating': 0.002637727845949461, 'error margin': 0.0014654043588608117, 'match count': 27}
# Matchup ('Zhao', 'Gage+'): {'rating': 0.03088338527024426, 'error margin': 0.04211370718669673, 'match count': 11}
# Matchup ('Tasha+', 'Penny+'): {'rating': -0.04042952059353551, 'error margin': -0.014791288022025187, 'match count': 41}
# Matchup ('Mira', 'Caulder'): {'rating': -0.04778825682001938, 'error margin': -0.11947064205004845, 'match count': 6}
# Matchup ('Will', 'Waylon+'): {'rating': 0.0434519507529225, 'error margin': 0.04655566152098838, 'match count': 14}
# Matchup ('Tasha+', 'Tabitha'): {'rating': -0.11900164227906697, 'error margin': -0.06611202348837054, 'match count': 27}
# Matchup ('Greyfield+', 'Lin'): {'rating': 0.0048309484890022465, 'error margin': 0.0072464227335033715, 'match count': 10}
# Matchup ('Lee', 'Gage+'): {'rating': 0.04676982255044819, 'error margin': 0.10022104832238897, 'match count': 7}
# Matchup ('Greyfield+', 'Caulder'): {'rating': -0.03249383960480281, 'error margin': -0.06962965629600601, 'match count': 7}
# Matchup ('The Beast', 'Greyfield+'): {'rating': -0.07135170854806082, 'error margin': -0.17837927137015208, 'match count': 6}
# Matchup ('The Fanatic', 'Lin'): {'rating': -0.0444078981151289, 'error margin': -0.08326480896586669, 'match count': 8}
# Matchup ('Forsythe', 'Tasha+'): {'rating': 0.02771827670249592, 'error margin': 0.031982626964418365, 'match count': 13}
# Matchup ('The Fanatic', 'Greyfield+'): {'rating': 0.0046559771964775985, 'error margin': 0.017459914486790996, 'match count': 4}
# Matchup ('Gage+', 'Waylon+'): {'rating': -0.03274028491635372, 'error margin': -0.061388034218163225, 'match count': 8}
# Matchup ('Zhao', 'The Fanatic'): {'rating': 0.08538350858759239, 'error margin': 0.3201881572034715, 'match count': 4}
# Matchup ('Tasha+', 'Waylon+'): {'rating': 0.0645731642192147, 'error margin': 0.08805431484438368, 'match count': 11}
# Matchup ('Penny+', 'Caulder'): {'rating': -0.017464649823733254, 'error margin': -0.007080263442054022, 'match count': 37}
# Matchup ('The Beast', 'Brenner-'): {'rating': 0.07952801288669557, 'error margin': 0.08520858523574527, 'match count': 14}
# Matchup ('The Beast', 'Waylon+'): {'rating': 0.10366576527751123, 'error margin': 0.25916441319377803, 'match count': 6}
# Matchup ('Cassie', 'Brenner-'): {'rating': -0.03712358408731841, 'error margin': -0.034803360081861016, 'match count': 16}
# Matchup ('Tasha+', 'Isabella-'): {'rating': -0.09386210812100075, 'error margin': -0.05214561562277818, 'match count': 27}
# Matchup ('The Fanatic', 'Caulder'): {'rating': -0.10178367440854368, 'error margin': -0.305351023225631, 'match count': 5}
# Matchup ('The Beast', 'Penny+'): {'rating': -0.08468905479376923, 'error margin': -0.04380468351401856, 'match count': 29}
# Matchup ('Zhao', 'Brenner-'): {'rating': -0.022881816654811805, 'error margin': -0.038136361091353016, 'match count': 9}
# Matchup ('Brenner-', 'Lin'): {'rating': 0.11332369966209599, 'error margin': 0.047218208192539995, 'match count': 36}
# Matchup ('Waylon+', 'Caulder'): {'rating': 0.05598670768798914, 'error margin': 0.10497507691497965, 'match count': 8}
# Matchup ('Will', 'Brenner-'): {'rating': -0.08458008548372621, 'error margin': -0.07048340456977185, 'match count': 18}
# Matchup ('Forsythe', 'Gage+'): {'rating': -0.09628229298226333, 'error margin': -0.18052929934174378, 'match count': 8}
# Matchup ('Will', 'Tinker'): {'rating': 0.03217178781978203, 'error margin': 0.09651536345934608, 'match count': 5}
# Matchup ('Lee', 'Tinker'): {'rating': 0.0671611316173789, 'error margin': 0.14391671060866906, 'match count': 7}
# Matchup ('The Fanatic', 'Hawke'): {'rating': 0.03393411345883963, 'error margin': 0.0636264627353243, 'match count': 8}
# Matchup ('Greyfield+', 'Hawke'): {'rating': -0.07898544275007247, 'error margin': -0.06969303772065216, 'match count': 17}
# Matchup ('Gage+', 'The Fanatic'): {'rating': -0.055563420382187395, 'error margin': -0.20836282643320272, 'match count': 4}
# Matchup ('Isabella-', 'Caulder'): {'rating': -0.024430177283557508, 'error margin': -0.021556038779609564, 'match count': 17}
# Matchup ('Tasha+', 'Hawke'): {'rating': -0.08727253277504184, 'error margin': -0.05034953813944722, 'match count': 26}
# Matchup ('Will', 'Gage+'): {'rating': 0.011802071585173853, 'error margin': 0.019670119308623092, 'match count': 9}
# Matchup ('Mira', 'Hawke'): {'rating': -0.03461543336851365, 'error margin': -0.03245196878298155, 'match count': 16}
# Matchup ('Tasha+', 'The Fanatic'): {'rating': -0.04513965835307316, 'error margin': -0.6770948752960974, 'match count': 1}
# Matchup ('Mira', 'Greyfield+'): {'rating': -0.046770852370036614, 'error margin': -0.14031255711010984, 'match count': 5}
# Matchup ('Waylon+', 'Hawke'): {'rating': 0.03383642919363718, 'error margin': 0.01586082618451743, 'match count': 32}
# Matchup ('The Fanatic', 'Waylon+'): {'rating': -0.020585586786971838, 'error margin': -0.051463966967429595, 'match count': 6}
# Matchup ('Will', 'Isabella-'): {'rating': -0.04759755933788016, 'error margin': -0.039664632781566796, 'match count': 18}
# Matchup ('Gage+', 'Tasha+'): {'rating': -0.17312261028502213, 'error margin': -0.19975685802117937, 'match count': 13}
# Matchup ('Isabella-', 'Hawke'): {'rating': -0.050993508512034415, 'error margin': -0.021247295213347665, 'match count': 36}
# Matchup ('Gage+', 'Isabella-'): {'rating': -0.11918962637840173, 'error margin': -0.11918962637840173, 'match count': 15}
# Matchup ('Isabella-', 'Lin'): {'rating': -0.131616061957947, 'error margin': -0.04591257975277219, 'match count': 43}
# Matchup ('Forsythe', 'Isabella-'): {'rating': 0.02842510503320235, 'error margin': 0.021318828774901766, 'match count': 20}
# Matchup ('Forsythe', 'Greyfield+'): {'rating': 0.01886588575764219, 'error margin': 0.02358235719705274, 'match count': 12}
# Matchup ('Zhao', 'Waylon+'): {'rating': 0.0877464177606913, 'error margin': 0.26323925328207387, 'match count': 5}
# Matchup ('Gage+', 'The Beast'): {'rating': -0.06197617280307313, 'error margin': -0.10329362133845521, 'match count': 9}
# Matchup ('Tinker', 'Caulder'): {'rating': -0.03488642348829826, 'error margin': -0.07475662176063913, 'match count': 7}
# Matchup ('Tinker', 'Forsythe'): {'rating': 0.06821333980956919, 'error margin': 0.5116000485717689, 'match count': 2}
# Matchup ('Tinker', 'Isabella-'): {'rating': 0.044416432880543394, 'error margin': 0.05552054110067925, 'match count': 12}
# Matchup ('Tinker', 'Tabitha'): {'rating': -0.033282803888388786, 'error margin': -0.08320700972097195, 'match count': 6}
# Matchup ('Tinker', 'The Beast'): {'rating': -0.058823529411764705, 'error margin': -0.4411764705882353, 'match count': 2}
# Matchup ('Tinker', 'Lin'): {'rating': 0.02236484577706363, 'error margin': 0.055912114442659075, 'match count': 6}
# Matchup ('Tinker', 'Tasha+'): {'rating': 0.027113454119095475, 'error margin': 0.13556727059547738, 'match count': 3}
# Matchup ('Lee', 'Greyfield+'): {'rating': 0.10421190299226803, 'error margin': 0.2233112206977172, 'match count': 7}
# Matchup ('Tinker', 'Hawke'): {'rating': 0.04870883485584702, 'error margin': 0.0811813914264117, 'match count': 9}
# Matchup ('Cassie', 'The Fanatic'): {'rating': 0.0009621281755160249, 'error margin': 0.0028863845265480748, 'match count': 5}
# Matchup ('Zhao', 'Isabella-'): {'rating': -0.010149033851787661, 'error margin': -0.1522355077768149, 'match count': 1}
# Matchup ('Waylon+', 'Snowind'): {'rating': -0.08866537454121888, 'error margin': -0.14777562423536483, 'match count': 9}
# Matchup ('Snowind', 'Caulder'): {'rating': -0.04723348397759622, 'error margin': -0.07085022596639434, 'match count': 10}
# Matchup ('Lee', 'Tasha+'): {'rating': 0.04923875028587857, 'error margin': 0.0671437503898344, 'match count': 11}
# Matchup ('Will', 'Snowind'): {'rating': -0.045653486514934394, 'error margin': -0.03804457209577866, 'match count': 18}
# Matchup ('Tinker', 'Brenner-'): {'rating': 0.019767269715951837, 'error margin': 0.05930180914785551, 'match count': 5}
# Matchup ('Gage+', 'Snowind'): {'rating': -0.12745640086473922, 'error margin': -0.2731208589958698, 'match count': 7}
# Matchup ('Lee', 'Snowind'): {'rating': -0.05931572911251742, 'error margin': -0.12710513381253732, 'match count': 7}
# Matchup ('Mira', 'Snowind'): {'rating': 0.02278401155585084, 'error margin': 0.1139200577792542, 'match count': 3}
# Matchup ('Snowind', 'Hawke'): {'rating': 0.180515613950256, 'error margin': 0.1425123268028337, 'match count': 19}
# Matchup ('Tasha+', 'Snowind'): {'rating': -0.0463359290329225, 'error margin': -0.06950389354938374, 'match count': 10}
# Matchup ('Zhao', 'Snowind'): {'rating': 0.0484443773026297, 'error margin': 0.12111094325657426, 'match count': 6}
# Matchup ('Penny+', 'Snowind'): {'rating': -0.0007382724356505318, 'error margin': -0.0004429634613903192, 'match count': 25}
# Matchup ('Snowind', 'Tabitha'): {'rating': -0.04130454430730405, 'error margin': -0.02478272658438243, 'match count': 25}
# Matchup ('Lee', 'Brenner-'): {'rating': -0.03247840849436405, 'error margin': -0.09743522548309215, 'match count': 5}
# Matchup ('Tinker', 'Zhao'): {'rating': -0.04772832860245373, 'error margin': -0.35796246451840297, 'match count': 2}
# Matchup ('Tinker', 'Snowind'): {'rating': -0.09233595127925612, 'error margin': -0.34625981729721045, 'match count': 4}
# Matchup ('Cassie', 'Snowind'): {'rating': -0.10103161987252536, 'error margin': -0.15154742980878805, 'match count': 10}
# Matchup ('The Fanatic', 'Brenner-'): {'rating': -0.042301648222913386, 'error margin': -0.1586311808359252, 'match count': 4}
# Matchup ('Snowind', 'Lin'): {'rating': 0.025503817134726513, 'error margin': 0.027325518358635545, 'match count': 14}
# Matchup ('Tinker', 'Waylon+'): {'rating': -0.026510133871160267, 'error margin': -0.099413002016851, 'match count': 4}
# Matchup ('The Beast', 'Caulder'): {'rating': 0.02377464200363754, 'error margin': 0.11887321001818771, 'match count': 3}
# Matchup ('Greyfield+', 'Brenner-'): {'rating': -0.12131344685575299, 'error margin': -0.15164180856969126, 'match count': 12}
# Matchup ('Forsythe', 'Snowind'): {'rating': -0.07079168014007697, 'error margin': -0.26546880052528865, 'match count': 4}
# Matchup ('Brenner-', 'Hawke'): {'rating': 0.041719960179685364, 'error margin': 0.019556231334227514, 'match count': 32}
# Matchup ('Isabella-', 'Snowind'): {'rating': -0.06860421145557653, 'error margin': -0.08575526431947066, 'match count': 12}
# Matchup ('The Beast', 'Snowind'): {'rating': -0.05208329233548317, 'error margin': -0.13020823083870792, 'match count': 6}
# Matchup ('Mira', 'Zhao'): {'rating': -0.023377461573301797, 'error margin': -0.11688730786650899, 'match count': 3}
# Matchup ('Mira', 'Lee'): {'rating': 0.12258119351665558, 'error margin': 0.2626739861071191, 'match count': 7}
# Matchup ('Mira', 'The Beast'): {'rating': 0.016028623710474553, 'error margin': 0.04808587113142366, 'match count': 5}
# Matchup ('Greyfield+', 'Snowind'): {'rating': -0.07321022461186417, 'error margin': -0.5490766845889813, 'match count': 2}
# Matchup ('The Fanatic', 'Isabella-'): {'rating': 0.09852721529843088, 'error margin': 0.14779082294764628, 'match count': 10}
# Matchup ('Brenner-', 'Snowind'): {'rating': 0.1901993097537893, 'error margin': 0.23774913719223661, 'match count': 12}
# Matchup ('The Fanatic', 'Snowind'): {'rating': 0.003936642419494235, 'error margin': 0.059049636292413527, 'match count': 1}
# Matchup ('Cassie', 'Isabella-'): {'rating': 0.12256996007037617, 'error margin': 0.09676575795029697, 'match count': 19}
# Matchup ('Judy', 'Tabitha'): {'rating': -0.03323179731875224, 'error margin': -0.16615898659376122, 'match count': 3}
# Matchup ('Cyrus', 'Penny+'): {'rating': 0.04823757014659452, 'error margin': 0.09044544402486474, 'match count': 8}
# Matchup ('Cyrus', 'Waylon+'): {'rating': 0.00931453019426082, 'error margin': 0.023286325485652046, 'match count': 6}
# Matchup ('Cyrus', 'Isabella-'): {'rating': -0.01635417995703799, 'error margin': -0.012911194702924726, 'match count': 19}
# Matchup ('Judy', 'Hawke'): {'rating': 0.06030555362988375, 'error margin': 0.18091666088965125, 'match count': 5}
# Matchup ('Penny+', 'Judy'): {'rating': -0.012171761751174457, 'error margin': -0.020286269585290756, 'match count': 9}
# Matchup ('Brenner-', 'Judy'): {'rating': 0.05224730058177864, 'error margin': 0.39185475436333983, 'match count': 2}
# Matchup ('Lee', 'Judy'): {'rating': 0.015181127266733452, 'error margin': 0.11385845450050089, 'match count': 2}
# Matchup ('Cyrus', 'Tabitha'): {'rating': -0.04499964207360554, 'error margin': -0.16874865777602077, 'match count': 4}
# Matchup ('Isabella-', 'Judy'): {'rating': -0.011043098120110348, 'error margin': -0.04141161795041381, 'match count': 4}
# Matchup ('Greyfield+', 'Judy'): {'rating': 0.04942488142482738, 'error margin': 0.7413732213724107, 'match count': 1}
# Matchup ('Cyrus', 'Brenner-'): {'rating': 0.024017794076088787, 'error margin': 0.05146670159161884, 'match count': 7}
# Matchup ('Will', 'Cyrus'): {'rating': -0.045845202955563165, 'error margin': -0.17191951108336187, 'match count': 4}
# Matchup ('Waylon+', 'Judy'): {'rating': 0.010604635508203921, 'error margin': 0.05302317754101961, 'match count': 3}
# Matchup ('Mira', 'Cyrus'): {'rating': 0.003325648058209422, 'error margin': 0.016628240291047112, 'match count': 3}
# Matchup ('Judy', 'Lin'): {'rating': 0.043999661390204746, 'error margin': 0.3299974604265356, 'match count': 2}
# Matchup ('Cyrus', 'Hawke'): {'rating': 0.036785055631732004, 'error margin': 0.05517758344759801, 'match count': 10}
# Matchup ('Mira', 'Waylon+'): {'rating': -0.01190526280793621, 'error margin': -0.04464473552976079, 'match count': 4}
# Matchup ('Gage+', 'Cyrus'): {'rating': -0.08080068921930217, 'error margin': -0.6060051691447662, 'match count': 2}
# Matchup ('The Beast', 'Judy'): {'rating': -0.06281943592448408, 'error margin': -0.31409717962242034, 'match count': 3}
# Matchup ('Cassie', 'Cyrus'): {'rating': -0.057189315481256386, 'error margin': -0.17156794644376916, 'match count': 5}
# Matchup ('Cyrus', 'Lin'): {'rating': 0.011081249476121342, 'error margin': 0.016621874214182014, 'match count': 10}
# Matchup ('Tasha+', 'Judy'): {'rating': -0.011272136594081921, 'error margin': -0.16908204891122883, 'match count': 1}
# Matchup ('The Beast', 'Cyrus'): {'rating': -0.0031613644776913364, 'error margin': -0.011855116791342513, 'match count': 4}
# Matchup ('Cyrus', 'Caulder'): {'rating': 0.02980154343879124, 'error margin': 0.2235115757909343, 'match count': 2}
# Matchup ('Forsythe', 'Cyrus'): {'rating': 0.03722510176298478, 'error margin': 0.09306275440746196, 'match count': 6}
# Matchup ('Lee', 'Cyrus'): {'rating': -0.0404928306683516, 'error margin': -0.20246415334175796, 'match count': 3}
# Matchup ('Tinker', 'Cyrus'): {'rating': 0.05468595668739775, 'error margin': 0.8202893503109663, 'match count': 1}
# Matchup ('The Fanatic', 'Cyrus'): {'rating': -0.019287415297509714, 'error margin': -0.14465561473132285, 'match count': 2}
# Matchup ('Lee', 'The Fanatic'): {'rating': 0.02634395297845358, 'error margin': 0.39515929467680366, 'match count': 1}
# Matchup ('Cyrus', 'Snowind'): {'rating': 0.010396095676035118, 'error margin': 0.15594143514052677, 'match count': 1}
# Matchup ('Tasha+', 'Cyrus'): {'rating': 0.027827788931532288, 'error margin': 0.20870841698649215, 'match count': 2}
# Matchup ('Cyrus', 'Greyfield+'): {'rating': -0.029273856385743296, 'error margin': -0.4391078457861494, 'match count': 1}

# %% [markdown]
# ## Create the matchup heatmap

# %% [markdown]
# ### Create a symetric matchup matrix

# %%
n = len(ROSTER)
matchup_matrix = np.full((n, n), 0.0)
error_matrix = np.full((n, n), 0.0)
match_count_matrix = np.full((n,n), 0)

# Fill the matrix with matchup ratings
co_to_idx = {co: idx for idx, co in enumerate(ROSTER.values())}

for (co1, co2), rating in matchup_results.items():
    i, j = co_to_idx[co1], co_to_idx[co2]
    matchup_matrix[i, j] = rating["rating"]
    matchup_matrix[j, i] = -rating["rating"]  # Symmetric relationship
    error_matrix[i,j] = rating["error margin"]
    error_matrix[i,j] = -rating["error margin"]
    match_count_matrix[i, j] = match_count_matrix[j, i] = rating["match count"]

# Create DataFrame with proper labels
matchup_df = pd.DataFrame(matchup_matrix, index=ROSTER.values(), columns=ROSTER.values())
error_df = pd.DataFrame(error_matrix, index=ROSTER.values(), columns=ROSTER.values())
match_count_df = pd.DataFrame(
    match_count_matrix, index=ROSTER.values(), columns=ROSTER.values()
)

# %% [markdown]
# ### Calculate average ratings, average error and total matches.

# %%
avg_ratings = matchup_df.copy().mean(axis=1)
avg_error = error_df.copy().mean(axis=1)
sum_matches = match_count_df.copy().sum(axis=1)

combined_df = pd.concat([avg_ratings, avg_error, sum_matches], axis=1)
combined_df.columns = ['avg_ratings', 'avg_error', 'sum_matches']

print(combined_df)
# Out:
#              avg_ratings  avg_error  sum_matches
# Brenner-        0.028396  -0.026314          348
# Isabella-      -0.015948   0.013149          420
# Lin            -0.006442   0.000824          587
# Will           -0.016547   0.004741          549
# Forsythe       -0.006271   0.007694          421
# Gage+          -0.033090   0.074122          226
# Tasha+         -0.019511   0.035956          299
# Greyfield+     -0.031777   0.004976          186
# Waylon+        -0.019302   0.000341          280
# Caulder         0.018514  -0.002112          324
# Penny+          0.000620   0.002092          642
# Tabitha         0.063127  -0.000942          538
# Cassie         -0.028295   0.016048          450
# Cyrus           0.008447   0.000180          100
# Grat           -0.020956   0.003637           92
# Hawke          -0.001780   0.000000          588
# Judy            0.001705  -0.014365           35
# Lee             0.015885  -0.037107          288
# Mira            0.026688  -0.035572          165
# Snowind         0.027831  -0.003092          205
# The Beast      -0.001994   0.003382          237
# The Fanatic    -0.019290   0.024356          100
# Tinker          0.001184  -0.036560           96
# Zhao            0.028808  -0.056822          164

# %% [markdown]
# ### Create the heatmaps

# %%
# Sort COs by average rating (descending)
sorted_cos = avg_ratings.sort_values(ascending=False).index.tolist()

display_heatmap(
    'CO Matchup Ratings\n(1 = Should always win, -1 = Should always lose)',
    'Matchup rating',
    matchup_df.loc[sorted_cos, sorted_cos],
    sorted_cos,
    avg_ratings[sorted_cos],
)

# %%
display_heatmap(
    'CO Matchup Ratings Error Margins',
    'Error',
    error_df.loc[sorted_cos, sorted_cos],
    sorted_cos,
    avg_error[sorted_cos],
)

# %%
display_heatmap(
    'CO Matchup Match Count',
    'Match Count',
    match_count_df.loc[sorted_cos, sorted_cos],
    sorted_cos,
    sum_matches[sorted_cos],
    True
)

# %% [markdown]
# ## Analysis
#
# These tables demonstrate a surprisingly high potential for upsets (a player with a lower elo rating win over a player with a higher one) for characters such as Tabitha, Snowind and Mira. Brenner- also has a strong showing. On the other hand Gage+ is severely underwhelming, and characters such as Judy and Tinker still hover around the center of the list due to matchup records at the single digits.
